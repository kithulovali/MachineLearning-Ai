# %%
import pandas as pd 

Dataset = {
    'name' : ["goffart","jean marc","kithulovali"],
    'ages' : [20,19,30]
}
print(Dataset)
# Out:
# {'name': ['goffart', 'jean marc', 'kithulovali'], 'ages': [20, 19, 30]}

# %%
import pandas 
dataset = pandas.DataFrame(Dataset)
print(dataset)
# Out:
#           name  ages
# 0      goffart    20
# 1    jean marc    19
# 2  kithulovali    30

# %%
#series 
import pandas as pd
import numpy as np
from numpy import random 
# 1 D array generation 
array1 = random.randint(100 , size = 20)
print(pd.Series(array1))
# Out:
# 0     37
# 1     21
# 2     69
# 3     95
# 4     28
# 5      4
# 6     39
# 7     75
# 8     47
# 9     35
# 10    36
# 11    66
# 12    36
# 13    64
# 14    13
# 15    92
# 16     1
# 17    17
# 18    53
# 19    38
# dtype: int32

# %%
import pandas as pd 
import numpy as np
from numpy import random 

dataset = random.randint(20 , size=(2,5))
#print(dataset)
pd_dataset = pd.DataFrame(dataset)
# rows location 
print(pd_dataset.loc[0])
# Out:
# 0     2
# 1    17
# 2     2
# 3    10
# 4     6
# Name: 0, dtype: int32

# %%
print(pd_dataset.loc[1])
# Out:
# 0     6
# 1    13
# 2     0
# 3     0
# 4    11
# Name: 1, dtype: int32

# %%
import pandas as pd 
Load_file = pd.read_csv('data.csv')
#print(Load_file.to_string())

# %%
import pandas as pd 
load_json = pd.read_json("data.json")
#print(load_json.to_string())

# %%
import pandas as pd 
load_file = pd.read_csv("data.csv")
#print(load_file.head(20))
print(load_file.info())s
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB
# None
