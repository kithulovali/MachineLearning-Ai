# %%
import numpy as np
from numpy import random
x = random.randint(100 , size=(3,50) )
print(x)
# Out:
# [[43 18 86 60 14 76 63 11 84 54 76 16  1 64 34 99 64 37 64 39 25 55 85 46
#   63 81 96  9 59 63 31 60 20 54 52 98 97 22 36 33 62 92 35 78 75 41  2 78
#   23 29]
#  [91 33 17 49 70 21 70 89 69  3 53 45 50 13 20 22 48 61 44 57 50 52 37 51
#   96 65 74 47 94 22 95 59  5 31 13 99 34 39 12 51 93 15 79 63 54 50  3 17
#   74 80]
#  [23 89 85 57 84 55 24 46 55 10 31 46 14 82 30 66 62  5 85 36 69 77 14 37
#   32 15  9 26 10 63 33 31 74 84 48 23 65 19 17 17 25 31 92 90  3 78 56 27
#   50 18]]

# %%
x = random.rand()
print(x)
# Out:
# 0.4995928723601808

# %%
x = random.rand(5)
print(x)
# Out:
# [0.06435665 0.71836025 0.2233832  0.28013383 0.28181777]

# %%
x = random.choice([10,50,70,80])
print(x)
# Out:
# 70
