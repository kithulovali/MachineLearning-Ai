# %%
import matplotlib.pyplot as plt
import numpy as np 
from numpy import random
# definning the axis 
x_axis = np.array([1,8])
y_axis = np.array([1,10])

#plotting the graph 
#plt.plot(x_axis,y_axis)
#plt.show()

# %%
# ploting mutiple ponts 
x_axis = np.array([1,2,3,4])
y_axis = np.array([3,8,1,10])

plt.plot(x_axis , y_axis)
plt.show()

# %%
y_axis = random.randint(5 ,size=5)
print(y_axis)
plt.plot(y_axis ,marker = 'o')
plt.show()

# %%
y_axis = random.randint(5, size =5)
plt.plot(y_axis , c='g', ls ='dotted' ,marker ='o')
plt.show()

# %%
#x_axis = random.randint(5 , size = 5)
y_axis = random.randint(5, size = 5)
plt.plot(y_axis , marker = '*', c = 'r' ,ls= 'dotted') 
plt.xlabel('random Xs')
plt.ylabel('random Ys') 
plt.grid()
plt.show()

# %%
# multiples plots on one figure 
# figure one 
#x_axis = random.randint(5 , size = 5)
y_axis = random.randint(5 , size = 5)
plt.subplot(2,1,1)
plt.plot(y_axis , marker ='*', c ='g')
plt.grid()
plt.xlabel('random Xs figure 1')
plt.ylabel('random Ys figure 1')
plt.title('ramdon figure 1')
plt.show()
#x_axis = random.randint(5 , size = 5)
y_axis = random.randint(5 , size = 5)
plt.subplot(2,1,2)
plt.grid()
plt.plot(y_axis , marker ='o',c= 'r')
plt.xlabel('random Xs figure 2')
plt.ylabel('random Ys figure 2')
plt.title('random figure 2 ')
plt.show()

# %%
# first random
x_axis = random.randint(100 , size = 15) 
y_axis = random.randint(100 , size = 15)
plt.scatter(x_axis , y_axis )

# second random
x_axis = random.randint(100 , size = 15) 
y_axis = random.randint(100 , size = 15) 
plt.scatter(x_axis , y_axis)  
plt.show()

# %%
h_num = np.random.normal(150 , 10 , 250)
print(h_num)
plt.hist(h_num)
plt.show()
# Out:
# [139.60478003 143.73924799 141.87187935 168.11726215 127.84895073
#  142.4756962  151.23657723 142.50153062 153.01330344 151.21950663
#  155.83553613 158.20176148 161.86940922 143.34782824 142.06972048
#  143.19811237 155.49521069 149.7645794  148.42279314 160.75999159
#  145.76535769 151.66443086 167.03323023 145.95937547 142.86905736
#  132.30323727 150.51642119 147.93562782 145.15637585 138.34567771
#  145.69108147 166.93441807 155.63554848 146.91418327 138.03759612
#  156.94459518 165.79591695 168.64482906 134.69195167 164.64473627
#  145.90916113 145.18232843 147.6121122  137.14871577 149.96550633
#  133.55888894 157.4672903  154.56050113 129.0612819  157.70681228
#  136.8369873  151.50542084 137.77667809 132.9386261  165.47493506
